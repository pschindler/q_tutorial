# %% [markdown]
# # Hello
#
# This is an example for an interactive tutorial. This example lives in a Jupyter notebook, where code can be executed. The next page can be viewed by pressing space. For the best experience put your browser in full-screen mode (press F11)

# %%
#This is python code
1+1
# Out:
# 2

# %% [markdown]
# ## Classical information
#
# In existing computers, the smallest unit of information is the _bit_, that can be in one of two states, often denoted as $|0\rangle$ and $|1\rangle$. In the following, we will use the representation of information on a sphere. Classical information is represente as points on the northpole and southpole.

# %%
# %matplotlib inline
from citizen_q import *
draw_ground()

# %% [markdown]
# ## From bits to qubits
#
#
#
# In quantum information processing, the smallest unit of information is the _qubit_ that is, similarly to the classical case, embedded in a two-level system. Since the qubit is a quantum object it can also be in a _quantum superposition_ of the two states. The most general state $|\Psi \rangle$ of the qubit can be written as:
#
# $\Psi = \alpha |0\rangle + \beta |1\rangle$
#
# Due to the interpretation of the quantum state as a probability amplitude, the complex coefficients $\alpha$ and $\beta$ need to be normalized: $\alpha^2 + \beta^2 = 1$.

# %%
draw_superposition()

# %% [markdown]
# The sphere above corresponds to the state  $|\Psi_1\rangle  = 1/ \sqrt{2} \, (|0 \rangle + |1\rangle$
# which is known as a superposition state that has no classical analogon.

# %% [markdown]
# ## Creating a superposition
# Let's create a superposition from a classical state. First, we will need a qubit in the ground state which is already defined in our helper library.

# %%
psi = ground_state()

# %% [markdown]
# The state of a qubit can then be manipulated by performing _rotations_ around axes on the Bloch sphere.
# For example, we will rotate the ground state by 45° around the x-axis, which we can so by multiplying the state with the python command _rx(angle)_

# %%
psi45 = rx(pi/4)*psi

# %% [markdown]
# The resulting state can then be displayed using the command show_sphere()

# %%
show_sphere(psi45)

# %% [markdown]
# ## Your first assignment
# It's time for your first task. Using the formalism introduced above, generate an equal superposition between the two states $|0\rangle$ and $|1\rangle$.
# Type your code in the line below. Press shift-enter after editing to show your results.

# %%
# %matplotlib inline
from citizen_q import *
# Let's get the ground state
psi = ground_state()

# Edit the next line to generate an equal superposition (hint: use rx() * psi)
psi90 = rx(0) * psi

#Let's see what state we have generated:
show_sphere(psi90)
